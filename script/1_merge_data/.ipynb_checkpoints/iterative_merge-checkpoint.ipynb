# %%
# %run header_data_treatment.ipynb

# %%
works_au_af = spark.read.format('parquet').load('file:\\' + openalex_path + 'works_au_af.parquet')
df_scanR = spark.read.format('parquet').load('file:\\' + scanR_path + 'publications.parquet')
df_au_scanR = spark.read.format('parquet').load('file:\\' + scanR_path + 'authors.parquet')

merge_path = 'D:\\openalex-snapshot\\merge\\'

merge_pub = spark.read.format('parquet').load('file:\\' + merge_path + 'merge_oa_scanr.parquet')
merge_authors = spark.read.format('parquet').load('file:\\' + merge_path + 'merge_oa_scanr_authors.parquet').withColumnRenamed('id','idref')

# %%
expr_language ='CASE '+' '.join(
    ['WHEN title.' + field + ' IS NOT NULL THEN "'+ field + '"' for field in df_scanR.select('title.*').columns if field != 'default']) + 'ELSE NULL  END'

# %%
df_authors = (spark.read.format('parquet').load('file:\\' + openalex_path + 'authors.parquet')
              .withColumn('split_name', func.split(func.col('display_name'), ' '))
             .withColumn('first_name', func.element_at(func.col('split_name'), 1))
              .withColumn('last_name', func.concat_ws(' ', func.array_except(func.col('split_name'), func.array(func.col('first_name')))))
             )

# %%
works_au_af_w_names = (works_au_af
                      .join(df_authors
                      .withColumn('author_id', func.regexp_replace(func.col('id'), 'https://openalex.org/',''))
                      .select('author_id', 'display_name', 'first_name', 'last_name'), on = ['author_id'], how = 'left')
                      )
works_au_af_w_names.cache()
works_au_af_w_names.show()

# %%
df_scanR_exploded = (df_scanR
                     .withColumn('language', func.expr(expr_language))
                     .withColumn('authors', func.explode(func.col('authors')))
                     .withColumn('idref', func.regexp_replace(func.lower(func.col("authors.person")), 'idref',''))
                     .withColumn('firstName', func.regexp_replace(func.col('authors.firstName'), '\.', ''))
                     .withColumn('lastName', func.regexp_replace(func.col('authors.lastName'), '\.', ''))
                     .withColumn('fullName', func.regexp_replace(func.col('authors.fullName'), '\.', ''))
                     .withColumn('initial', func.substring(func.col('firstName'),1,1))
                     .withColumn('idref', func.when((func.col('idref').isNull()) & (func.col('productionType')!= 'thesis'), 
                                                func.col('fullName'))
                            .when( (func.col('idref').isNull()) & (func.col('productionType')=='thesis'),
                                                                    func.first(func.col('idref'), ignorenulls = True).over(Window.partitionBy('lastName','initial')))
                             .otherwise(func.col('idref')))
                     .withColumn('title', func.col('title.default'))
                    )

df_scanR_exploded.cache()
df_scanR_exploded.show()

# %%
df_scanR.printSchema()
# Out:
# root
#  |-- affiliations: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- acronym: struct (nullable = true)
#  |    |    |    |-- default: string (nullable = true)
#  |    |    |    |-- en: string (nullable = true)
#  |    |    |    |-- fr: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- id_name: string (nullable = true)
#  |    |    |-- isFrench: boolean (nullable = true)
#  |    |    |-- kind: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- label: struct (nullable = true)
#  |    |    |    |-- default: string (nullable = true)
#  |    |    |    |-- en: string (nullable = true)
#  |    |    |    |-- fr: string (nullable = true)
#  |    |    |-- level: string (nullable = true)
#  |    |    |-- mainAddress: struct (nullable = true)
#  |    |    |    |-- address: string (nullable = true)
#  |    |    |    |-- city: string (nullable = true)
#  |    |    |    |-- country: string (nullable = true)
#  |    |    |    |-- gps: struct (nullable = true)
#  |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |-- lon: double (nullable = true)
#  |    |    |    |-- postcode: string (nullable = true)
#  |    |    |-- status: string (nullable = true)
#  |-- authors: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- affiliations: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- BNF: string (nullable = true)
#  |    |    |    |    |-- ISNI: string (nullable = true)
#  |    |    |    |    |-- acronym: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- address: string (nullable = true)
#  |    |    |    |    |-- address-line: string (nullable = true)
#  |    |    |    |    |-- addresses: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- alias_idref: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- aliases: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |-- comments: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- country: string (nullable = true)
#  |    |    |    |    |-- datasource: string (nullable = true)
#  |    |    |    |    |-- department: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- detected_countries: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- docid: string (nullable = true)
#  |    |    |    |    |-- external_ids: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- id_type: string (nullable = true)
#  |    |    |    |    |    |    |-- id_value: string (nullable = true)
#  |    |    |    |    |-- grid: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- hal_docid: string (nullable = true)
#  |    |    |    |    |-- id: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- asserted-by: string (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- id-type: string (nullable = true)
#  |    |    |    |    |-- idref: string (nullable = true)
#  |    |    |    |    |-- ids: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- orgs: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- place: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- postal-code: string (nullable = true)
#  |    |    |    |    |-- rnsr: string (nullable = true)
#  |    |    |    |    |-- ror: string (nullable = true)
#  |    |    |    |    |-- structId: string (nullable = true)
#  |    |    |    |    |-- viaf: string (nullable = true)
#  |    |    |    |    |-- websites: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- zipcode: string (nullable = true)
#  |    |    |-- denormalized: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- id_hal: string (nullable = true)
#  |    |    |    |-- idref: string (nullable = true)
#  |    |    |    |-- orcid: string (nullable = true)
#  |    |    |-- firstName: string (nullable = true)
#  |    |    |-- fullName: string (nullable = true)
#  |    |    |-- id_name: string (nullable = true)
#  |    |    |-- lastName: string (nullable = true)
#  |    |    |-- person: string (nullable = true)
#  |    |    |-- role: string (nullable = true)
#  |    |    |-- toIdentify: string (nullable = true)
#  |-- authorsCount: long (nullable = true)
#  |-- autocompleted: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- autocompletedJournal: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- autocompletedPublisher: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- bso_local_affiliations: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- co_authors: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- co_domains: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- co_institutions: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- co_software: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- co_structures: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- doiUrl: string (nullable = true)
#  |-- domains: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- code: string (nullable = true)
#  |    |    |-- count: long (nullable = true)
#  |    |    |-- id_name: string (nullable = true)
#  |    |    |-- label: struct (nullable = true)
#  |    |    |    |-- default: string (nullable = true)
#  |    |    |-- naturalKey: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- externalIds: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- isOa: boolean (nullable = true)
#  |-- keywords: struct (nullable = true)
#  |    |-- default: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- landingPage: string (nullable = true)
#  |-- oaEvidence: struct (nullable = true)
#  |    |-- hostType: string (nullable = true)
#  |    |-- landingPageUrl: string (nullable = true)
#  |    |-- license: string (nullable = true)
#  |    |-- pdfUrl: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |    |-- version: string (nullable = true)
#  |-- pdfUrl: string (nullable = true)
#  |-- productionType: string (nullable = true)
#  |-- projects: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- acronym: struct (nullable = true)
#  |    |    |    |-- default: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- id_name: string (nullable = true)
#  |    |    |-- label: struct (nullable = true)
#  |    |    |    |-- en: string (nullable = true)
#  |    |    |    |-- fr: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- year: double (nullable = true)
#  |-- publicationDate: string (nullable = true)
#  |-- softwares: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- contexts: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id_name: string (nullable = true)
#  |    |    |-- softwareName: string (nullable = true)
#  |    |    |-- wikidata: string (nullable = true)
#  |-- source: struct (nullable = true)
#  |    |-- isInDoaj: boolean (nullable = true)
#  |    |-- isOa: boolean (nullable = true)
#  |    |-- journalIssns: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- publisher: string (nullable = true)
#  |    |-- title: string (nullable = true)
#  |-- summary: struct (nullable = true)
#  |    |-- default: string (nullable = true)
#  |    |-- en: string (nullable = true)
#  |    |-- fr: string (nullable = true)
#  |-- title: struct (nullable = true)
#  |    |-- af: string (nullable = true)
#  |    |-- an: string (nullable = true)
#  |    |-- ar: string (nullable = true)
#  |    |-- az: string (nullable = true)
#  |    |-- be: string (nullable = true)
#  |    |-- bg: string (nullable = true)
#  |    |-- bn: string (nullable = true)
#  |    |-- bo: string (nullable = true)
#  |    |-- br: string (nullable = true)
#  |    |-- bs: string (nullable = true)
#  |    |-- ca: string (nullable = true)
#  |    |-- cs: string (nullable = true)
#  |    |-- cy: string (nullable = true)
#  |    |-- da: string (nullable = true)
#  |    |-- de: string (nullable = true)
#  |    |-- default: string (nullable = true)
#  |    |-- el: string (nullable = true)
#  |    |-- en: string (nullable = true)
#  |    |-- eo: string (nullable = true)
#  |    |-- es: string (nullable = true)
#  |    |-- et: string (nullable = true)
#  |    |-- eu: string (nullable = true)
#  |    |-- fa: string (nullable = true)
#  |    |-- fi: string (nullable = true)
#  |    |-- fr: string (nullable = true)
#  |    |-- fy: string (nullable = true)
#  |    |-- ga: string (nullable = true)
#  |    |-- gb: string (nullable = true)
#  |    |-- gd: string (nullable = true)
#  |    |-- gl: string (nullable = true)
#  |    |-- gu: string (nullable = true)
#  |    |-- he: string (nullable = true)
#  |    |-- hi: string (nullable = true)
#  |    |-- hr: string (nullable = true)
#  |    |-- ht: string (nullable = true)
#  |    |-- hu: string (nullable = true)
#  |    |-- hy: string (nullable = true)
#  |    |-- ia: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- ie: string (nullable = true)
#  |    |-- in: string (nullable = true)
#  |    |-- io: string (nullable = true)
#  |    |-- is: string (nullable = true)
#  |    |-- it: string (nullable = true)
#  |    |-- ja: string (nullable = true)
#  |    |-- jv: string (nullable = true)
#  |    |-- kk: string (nullable = true)
#  |    |-- km: string (nullable = true)
#  |    |-- kn: string (nullable = true)
#  |    |-- ko: string (nullable = true)
#  |    |-- ku: string (nullable = true)
#  |    |-- kw: string (nullable = true)
#  |    |-- la: string (nullable = true)
#  |    |-- lb: string (nullable = true)
#  |    |-- lt: string (nullable = true)
#  |    |-- lv: string (nullable = true)
#  |    |-- mg: string (nullable = true)
#  |    |-- mk: string (nullable = true)
#  |    |-- ml: string (nullable = true)
#  |    |-- mn: string (nullable = true)
#  |    |-- mr: string (nullable = true)
#  |    |-- ms: string (nullable = true)
#  |    |-- my: string (nullable = true)
#  |    |-- nb: string (nullable = true)
#  |    |-- ne: string (nullable = true)
#  |    |-- nl: string (nullable = true)
#  |    |-- nn: string (nullable = true)
#  |    |-- no: string (nullable = true)
#  |    |-- oc: string (nullable = true)
#  |    |-- pl: string (nullable = true)
#  |    |-- po: string (nullable = true)
#  |    |-- ps: string (nullable = true)
#  |    |-- pt: string (nullable = true)
#  |    |-- qu: string (nullable = true)
#  |    |-- rm: string (nullable = true)
#  |    |-- ro: string (nullable = true)
#  |    |-- ru: string (nullable = true)
#  |    |-- sa: string (nullable = true)
#  |    |-- sh: string (nullable = true)
#  |    |-- si: string (nullable = true)
#  |    |-- sk: string (nullable = true)
#  |    |-- sl: string (nullable = true)
#  |    |-- sq: string (nullable = true)
#  |    |-- sr: string (nullable = true)
#  |    |-- su: string (nullable = true)
#  |    |-- sv: string (nullable = true)
#  |    |-- sw: string (nullable = true)
#  |    |-- ta: string (nullable = true)
#  |    |-- te: string (nullable = true)
#  |    |-- th: string (nullable = true)
#  |    |-- tl: string (nullable = true)
#  |    |-- tr: string (nullable = true)
#  |    |-- tt: string (nullable = true)
#  |    |-- uk: string (nullable = true)
#  |    |-- ur: string (nullable = true)
#  |    |-- uz: string (nullable = true)
#  |    |-- vi: string (nullable = true)
#  |    |-- vo: string (nullable = true)
#  |    |-- wa: string (nullable = true)
#  |    |-- zh: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- vector_text: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- year: long (nullable = true)

# %%
import unidecode
def unidecode_debug(x):
    try:
        y = unidecode.unidecode(x)
        return(y)
    except:
        return(x)

udf_unidecode = func.udf(unidecode_debug, StringType())

import nltk
from nltk.corpus import stopwords
print(stopwords.fileids())
stopwords_dict = {}
for language in stopwords.fileids():
    stopwords_dict[language.capitalize()] = stopwords.words(language)

values = [(k, stopwords_dict[k]) for k in list(stopwords_dict.keys())]
columns = ['language', 'stopwords']
stopwords_df = spark.createDataFrame(values, columns)

iso_639_choices ={
'ab': 'Abkhaz', 'aa': 'Afar', 'af': 'Afrikaans', 'ak': 'Akan', 'sq': 'Albanian', 'am': 'Amharic', 'ar': 'Arabic',
'an': 'Aragonese', 'hy': 'Armenian', 'as': 'Assamese', 'av': 'Avaric', 'ae': 'Avestan', 'ay': 'Aymara', 'az': 'Azerbaijani',
'bm': 'Bambara', 'ba': 'Bashkir', 'eu': 'Basque', 'be': 'Belarusian', 'bn': 'Bengali', 'bh': 'Bihari', 'bi': 'Bislama',
'bs': 'Bosnian', 'br': 'Breton', 'bg': 'Bulgarian', 'my': 'Burmese', 'ca': 'Catalan; Valencian', 'ch': 'Chamorro', 'ce': 'Chechen',
'ny': 'Chichewa; Chewa; Nyanja', 'zh': 'Chinese', 'cv': 'Chuvash', 'kw': 'Cornish', 'co': 'Corsican', 'cr': 'Cree', 'hr': 'Croatian',
'cs': 'Czech', 'da': 'Danish', 'dv': 'Divehi; Maldivian;', 'nl': 'Dutch', 'dz': 'Dzongkha', 'en': 'English', 'eo': 'Esperanto',
'et': 'Estonian', 'ee': 'Ewe', 'fo': 'Faroese', 'fj': 'Fijian', 'fi': 'Finnish', 'fr': 'French', 'ff': 'Fula', 'gl': 'Galician',
'ka': 'Georgian', 'de': 'German', 'el': 'Greek', 'gn': 'Guaraní', 'gu': 'Gujarati', 'ht': 'Haitian','ha': 'Hausa',
'he': 'Hebrew','hz': 'Herero','hi': 'Hindi','hi': 'Hinglish','ho': 'Hiri Motu','hu': 'Hungarian','ia': 'Interlingua','id': 'Indonesian',
'ie': 'Interlingue','ga': 'Irish','ig': 'Igbo','ik': 'Inupiaq','io': 'Ido','is': 'Icelandic','it': 'Italian','iu': 'Inuktitut',
'ja': 'Japanese','jv': 'Javanese', 'kl': 'Kalaallisut', 'kn': 'Kannada', 'kr': 'Kanuri', 'ks': 'Kashmiri', 
'kk': 'Kazakh', 'km': 'Khmer', 'ki': 'Kikuyu, Gikuyu', 'rw': 'Kinyarwanda', 'ky': 'Kirghiz, Kyrgyz', 'kv': 'Komi', 
'kg': 'Kongo', 'ko': 'Korean', 'ku': 'Kurdish', 'kj': 'Kwanyama, Kuanyama', 'la': 'Latin', 'lb': 'Luxembourgish', 
'lg': 'Luganda', 'li': 'Limburgish', 'ln': 'Lingala', 'lo': 'Lao', 'lt': 'Lithuanian', 'lu': 'Luba-Katanga', 'lv': 'Latvian',
'gv': 'Manx', 'mk': 'Macedonian', 'mg': 'Malagasy', 'ms': 'Malay', 'ml': 'Malayalam', 'mt': 'Maltese', 'mi': 'Māori', 
'mr': 'Marathi','mh': 'Marshallese','mn': 'Mongolian','na': 'Nauru','nv': 'Navajo','nb': 'Norwegian Bokmål',
'nd': 'North Ndebele','ne': 'Nepali','ng': 'Ndonga','nn': 'Norwegian Nynorsk','no': 'Norwegian','ii': 'Nuosu',
'nr': 'South Ndebele','oc': 'Occitan','oj': 'Ojibwe, Ojibwa','cu': 'Old Church Slavonic','om': 'Oromo','or': 'Oriya',
'os': 'Ossetian, Ossetic','pa': 'Panjabi, Punjabi','pi': 'Pāli','fa': 'Persian','pl': 'Polish','ps': 'Pashto, Pushto',
'pt': 'Portuguese','qu': 'Quechua','rm': 'Romansh','rn': 'Kirundi', 'ro': 'Romanian', 'ru': 'Russian', 
'sa': 'Sanskrit (Saṁskṛta)', 'sc': 'Sardinian', 'sd': 'Sindhi', 'se': 'Northern Sami', 'sm': 'Samoan', 'sg': 'Sango',
'sr': 'Serbian', 'gd': 'Scottish Gaelic', 'sn': 'Shona', 'si': 'Sinhala, Sinhalese', 'sk': 'Slovak', 'sl': 'Slovene',
'so': 'Somali', 'st': 'Southern Sotho', 'es': 'Spanish', 'su': 'Sundanese', 'sw': 'Swahili', 'ss': 'Swati', 'sv': 'Swedish', 
'ta': 'Tamil', 'te': 'Telugu', 'tg': 'Tajik', 'th': 'Thai', 'ti': 'Tigrinya','bo': 'Tibetan','tk': 'Turkmen','tl': 'Tagalog','tn': 'Tswana','to': 'Tonga','tr': 'Turkish','ts': 'Tsonga','tt': 'Tatar','tw': 'Twi','ty': 'Tahitian','ug': 'Uighur, Uyghur','uk': 'Ukrainian','ur': 'Urdu','uz': 'Uzbek','ve': 'Venda','vi': 'Vietnamese','vo': 'Volapük','wa': 'Walloon','cy': 'Welsh','wo': 'Wolof','fy': 'Western Frisian','xh': 'Xhosa','yi': 'Yiddish','yo': 'Yoruba','za': 'Zhuang, Chuang',
'zu': 'Zulu', "zh-cn" : "Chinese"
}
        

values = [(k, iso_639_choices[k]) for k in list(iso_639_choices.keys())]
columns = ["language_iso2",'language']
iso_df = spark.createDataFrame(values, columns)
#iso_df.show()

stopwords_df = (stopwords_df.join(iso_df.withColumn('language', func.explode(func.split(func.col('language'), '; '))), on = 'language', how = 'left')
                .select('stopwords', func.col('language_iso2').alias('language'))
               )
def rm_stopwords(x,y):
    if x is None:
        return(x)
    if y is None:
        return(y)
    else:
        try:
            list_x = x.split(' ')
            list_y = y
            return(' '.join([word for word in list_x if word not in list_y]))
        except:
            return(x)
udf_rm_stopwords = func.udf(rm_stopwords)
#stopwords_df.show()
# Out:
# ['arabic', 'azerbaijani', 'basque', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']

# %%
def get_only_unmatched(base_1, base_2, merged, id_1, id_2):

    unmatched_1 = (base_1
                   .join(merged.select(id_1), on = id_1, how = 'leftanti')
                  )
    unmatched_2 = (base_2
                   .join(merged.select(id_2), on = id_2, how = 'leftanti')
                  )
    return(unmatched_1, unmatched_2)

# %%
def match_authors_from_pub(merged, base_1, base_2, pub_id_1, pub_id_2,
                           au_id_1, au_id_2, last_name_1, last_name_2, name_1, name_2):

    to_merge_1 = (base_1
                .join(merged.select(pub_id_1), on = pub_id_1, how = 'inner')
                .select(au_id_1, func.substring(func.col(name_1), 1, 1).alias('initial'), func.col(last_name_1).alias('last_name'), pub_id_1)
               )
    #print(to_merge_1.count())
    to_merge_2 = (base_2
                .join(merged.select(pub_id_1, pub_id_2), on = pub_id_2, how = 'inner')
                .select(au_id_2, func.substring(func.col(name_2), 1, 1).alias('initial'), func.col(last_name_2).alias('last_name'), pub_id_1, pub_id_2)
                 )
    #print(to_merge_2.count())
    matched = (to_merge_1
               .join(to_merge_2, on = [pub_id_1, 'last_name', 'initial'], how = 'inner')
               .withColumn('n_diff_id_1', func.size(func.collect_set(func.col(au_id_1)).over(Window.partitionBy(au_id_2))))
               .withColumn('n_diff_id_2', func.size(func.collect_set(func.col(au_id_2)).over(Window.partitionBy(au_id_1))))
               .filter( (func.col('n_diff_id_1')==1) &  (func.col('n_diff_id_2')==1))
               .select(au_id_1, au_id_2)
               .distinct()
              )
    return(matched)

# %%
def match_pubs_from_authors(merged, base_1, base_2, pub_id_1, pub_id_2,
                           au_id_1, au_id_2, title):

    to_merge_1 = (base_1
                .join(merged.select(au_id_1), on = au_id_1, how = 'inner')
                .join(stopwords_df, on = ['language'], how = 'left')
                .withColumn('cleaned_title', udf_rm_stopwords(func.lower(func.col(title)), func.col('stopwords')))
                .withColumn('cleaned_title', udf_unidecode(func.col('cleaned_title')))
                .withColumn('cleaned_title', func.regexp_replace(func.col('cleaned_title'), r'[[^A-Za-z0-9 -]]+', ''))  # Remove special characters
                .withColumn('cleaned_title', func.regexp_replace(func.col('cleaned_title'), '  ', ''))  # Remove special characters
                .withColumn('cleaned_title', func.regexp_replace(func.col('cleaned_title'), '  ', ''))  # Remove special characters
                .select(au_id_1, 'cleaned_title', pub_id_1)
               )
    print(to_merge_1.count())
    to_merge_2 = (base_2
                .join(merged.select(au_id_1, au_id_2), on = au_id_2, how = 'inner')
                .join(stopwords_df, on = ['language'], how = 'left')
                .withColumn('cleaned_title', udf_rm_stopwords(func.lower(func.col(title)), func.col('stopwords')))
                .withColumn('cleaned_title', udf_unidecode(func.col('cleaned_title')))
                .withColumn('cleaned_title', func.regexp_replace(func.col('cleaned_title'), r'[[^A-Za-z0-9 -]]+', ''))  # Remove special characters
                .withColumn('cleaned_title', func.regexp_replace(func.col('cleaned_title'), '  ', ''))  # Remove special characters
                .withColumn('cleaned_title', func.regexp_replace(func.col('cleaned_title'), '  ', ''))  # Remove special characters
                .select(au_id_1, au_id_2, 'cleaned_title', pub_id_2)
                 )
    print(to_merge_2.count())

    matched = (to_merge_1
               .join(to_merge_2, on = [au_id_1, 'cleaned_title'], how = 'inner')
               .withColumn('n_diff_id_1', func.size(func.collect_set(func.col(pub_id_1)).over(Window.partitionBy(pub_id_2))))
               .withColumn('n_diff_id_2', func.size(func.collect_set(func.col(pub_id_2)).over(Window.partitionBy(pub_id_1))))
               .filter( (func.col('n_diff_id_1')==1) &  (func.col('n_diff_id_2')==1))
               .select(pub_id_1, pub_id_2)
               .distinct()
              )
    return(matched)

# %%
iterations = 0
while iterations < 1:
    iterations = iterations +1
    print('Iteration: ', iterations + 1)
    merge_pub = spark.read.format('parquet').load('file:\\' + merge_path + 'merge_oa_scanr.parquet')
    merge_authors = spark.read.format('parquet').load('file:\\' + merge_path + 'merge_oa_scanr_authors.parquet').withColumnRenamed('id','idref')

    print('Nr matches for publications: ' merge_pub.count(), ', nr matches for authors: ',    merge_authors.count())

    
    unmatched_pubs_oa, unmatched_pubs_scanR = get_only_unmatched(works_au_af_w_names, df_scanR_exploded, merge_pub, 'work_id', 'id')
    unmatched_au_oa, unmatched_au_scanR = get_only_unmatched(works_au_af_w_names, df_scanR_exploded, merge_authors, 'author_id', 'idref')

    print('ok')
    new_match_au_from_pubs = match_authors_from_pub(merge_pub, unmatched_au_oa, unmatched_au_scanR, 'work_id', 'id',
                           'author_id', 'idref', 'last_name', 'lastName', 'display_name', 'fullName')
    
    new_match_pubs_from_au = match_pubs_from_authors(merge_authors, unmatched_pubs_oa, unmatched_pubs_scanR, 'work_id', 'id',
                           'author_id', 'idref', 'title')

    merged_authors = (merged_authors.unionAll(new_match_au_from_pubs))
    merge_pub = (merge_pub.unionAll(new_match_pubs_from_au))
        
    merged_authors.write.mode('overwrite').parquet('file:\\' + merge_path + 'merge_oa_scanr_authors.parquet')
    merge_pub.write.mode('overwrite').parquet('file:\\' + merge_path + 'merge_oa_scanr.parquet')
    #print('New matches of authors from publications : ', new_match_au_from_pubs.count(), '\n',
    #      'New matches of publications from authors : ', new_match_pubs_from_au.count())
# Out:
# ok
# 0
# 0
# 38338654
# 0

# %%
unmatched_pubs_oa, unmatched_pubs_scanR = get_only_unmatched(works_au_af_w_names, df_scanR_exploded, merge_pub, 'work_id', 'id')

# %%
unmatched_au_oa, unmatched_au_scanR = get_only_unmatched(works_au_af_w_names, df_scanR_exploded, merge_authors, 'author_id', 'idref')

# %%
match_pubs_from_authors(merge_authors, unmatched_pubs_oa, unmatched_pubs_scanR, 'work_id', 'id',
                           'author_id', 'idref', 'title')
# Out:
# 38338654
# 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 match_pubs_from_authors(merge_authors, unmatched_pubs_oa, unmatched_pubs_scanR, 'work_id', 'id',
#       2                            'author_id', 'idref', 'title')
# ----> 3 match_pubs_from_authors.show()
#
# AttributeError: 'function' object has no attribute 'show'

# %%
merge_authors[].show()
# Out:
# +--------------+-----------+
# |         idref|  author_id|
# +--------------+-----------+
# |idref108538427|A5080431922|
# |idref225993244|A5009476002|
# |idref17820806X|A5045317380|
# |idref097879134|A5043440547|
# |idref079013848|A5091569743|
# |idref27199214X|A5073550025|
# |idref117817007|A5079720434|
# |idref258447958|A5018502157|
# |idref140407960|A5007698196|
# |idref221650709|A5018830374|
# |idref081786883|A5040388573|
# |idref078649781|A5065112242|
# |idref178968315|A5005892790|
# |idref250398206|A5078787536|
# |idref25101651X|A5072381169|
# |idref165190132|A5028531834|
# |idref175449716|A5009278937|
# |idref232567670|A5079074755|
# |idref116414014|A5002320268|
# |idref196687144|A5023926454|
# +--------------+-----------+
# only showing top 20 rows

# %%
df_scanR_exploded.select('idref').filter(func.col('idref').rlike('\d')).show()
# Out:
# +--------------------+
# |               idref|
# +--------------------+
# |076086224###g.maz...|
# |189607939###ouria...|
# |           Alice M 1|
# |Achille Cesare Pe...|
# |           Geloen 12|
# |Holger S Willenbe...|
# |             Huot 14|
# |Vila 1exmulri Mag...|
# |            342 Choi|
# |       457 Borgonovo|
# |  Leo Schultzekool 7|
# |145470768###aurél...|
# |076926656###aurél...|
# |169207226###renau...|
# |13028906x###tara ...|
# |13028906x###tara ...|
# |13028906x###tara ...|
# |13028906x###tara ...|
# |13028906x###tara ...|
# |13028906x###tara ...|
# +--------------------+
# only showing top 20 rows

# %%
(unmatched_au_scanR
                .join(merge_pub.select('work_id', 'id'), on = 'id', how = 'inner')
                .select('idref', func.substring(func.col('fullName'), 1, 1).alias('initial'), func.col('lastName').alias('last_name'), 'id','work_id')
                 ).show()
# Out:
# +--------------------+-------+--------------+--------------------+
# |               idref|initial|     last_name|                  id|
# +--------------------+-------+--------------+--------------------+
# |  Alain Palloix ( ‡)|      A|          ( ‡)|doi10.25518/1780-...|
# |              Goel A|      G|             A|doi10.16965/ijar....|
# |            Gevrey A|      G|             A|     halhal-02304673|
# |            Gevrey A|      G|             A|     halhal-02304776|
# |           Garnier A|      G|             A|     halhal-03566942|
# |          Harroche A|      H|             A|doi10.31031/rpn.2...|
# |         Houeijeh, A|      H|             A|     halhal-02466637|
# |           Lemaire A|      L|             A|doi10.16966/2378-...|
# |     Leitenstorfer A|      L|             A|doi10.1051/epjcon...|
# |  Lacorte-Bruguera A|      L|             A|     halhal-02332778|
# |      A Myrkassimova|      A|A Myrkassimova|doi10.32014/2019....|
# |     Larissa A Rolim|      L|       A Rolim|doi10.21577/1984-...|
# |     Habibah A Wahab|      H|       A Wahab|doi10.21315/jps20...|
# |Mohammed ABDUL SAMAD|      M|   ABDUL SAMAD|doi10.1016/s1003-...|
# |     AYMAN S ABUTAIR|      A|       ABUTAIR|doi10.12944/crnfs...|
# |        NEZAM AFDHAL|      N|        AFDHAL|doi10.2337/db19-1...|
# |199566828###achal...|      A|       AGRAWAL|doi10.1109/wimob....|
# |      GROUP AGRICAN-|      G|      AGRICAN-|doi10.1136/oem-20...|
# |     Oussama AHRAZEM|      O|       AHRAZEM|doi10.3906/bot-18...|
# |FLAVIO DE ALMEIDA...|      F|  ALVES-JÚNIOR|doi10.11646/zoota...|
# +--------------------+-------+--------------+--------------------+
# only showing top 20 rows

# %%
unmatched_pubs_oa.show()
# Out:
# +-----------+-----------+-----------+-----------+----------------+---------+------------+---------------+-------+---------+--------------------------------------+--------+----------------+--------------------+------------------+--------------------+----------+-----------------+
# |    work_id|  author_id|    inst_id|  source_id|publication_year|citations|        type|author_position|country|inst_type|                                 title|language|         version|              fields|     rank_by_field|        display_name|first_name|        last_name|
# +-----------+-----------+-----------+-----------+----------------+---------+------------+---------------+-------+---------+--------------------------------------+--------+----------------+--------------------+------------------+--------------------+----------+-----------------+
# |W1000086972|A5005748252|       NULL|       NULL|            2001|        0|     article|          first|   NULL|     NULL|                  PELICAN - Pricing...|      en|            NULL|[Biology, Busines...|               0.0|   Charles Oppenheim|   Charles|        Oppenheim|
# |W1000006948|A5007324954|       NULL|S4306552639|            1994|        0|     article|           last|   NULL|     NULL|        采伐调查设计(作业)成本速算初探|   zh-cn|            NULL|  [Computer science]|               0.0|              魏彦彬|    魏彦彬|                 |
# | W100000914|A5011035542|       NULL|S4210194219|            1973|        0|     article|          first|   NULL|     NULL|                  Geology and miner...|      en|publishedVersion|           [Geology]|               0.0|           R.B. Hall|      R.B.|             Hall|
# |W1000062617|A5012306549|       NULL|S4210182227|            2005|        0|     article|          first|   NULL|     NULL|                  Liberale Demokrat...|      de|            NULL|[Philosophy, Poli...|               0.0|       Richard Saage|   Richard|            Saage|
# | W100012731|A5015778850|       NULL|S4306526548|            2000|        0|     article|           last|   NULL|     NULL|                  Effects of water ...|      en|            NULL|[Biology, Environ...|               0.0|   J. Silveira Filho|        J.|   Silveira Filho|
# |W1000132866|A5017183161|       NULL|S4306554696|            2001|        0|     article|           last|   NULL|     NULL|  抓农业生态环境建设 走质量效益农业...|   zh-cn|            NULL|  [Computer science]|               0.0|              董玉芹|    董玉芹|                 |
# |W1000054759|A5017812851|I4210098952|  S76304953|            2010|        1|     article|           last|     US|  company|                  The ArgusTM II Re...|      en|            NULL|[Computer science...|50.485857146070195|      R.J. Greenberg|      R.J.|        Greenberg|
# |W1000046334|A5018492358|       NULL|S4306544079|            2014|        0|     article|         middle|   NULL|     NULL|  猪皮下和内脏脂肪组织中G蛋白偶联受...|   zh-cn|            NULL|           [Biology]|               0.0|              王红梅|    王红梅|                 |
# | W100002715|A5022417632|       NULL|S2764680408|            2003|       59|book-chapter|          first|   NULL|     NULL|                  Root Exudates: an...|      en|            NULL|        [Philosophy]|  94.4001485453826|   Inderjit Inderjit|  Inderjit|                 |
# |W1000049952|A5023100723|       NULL| S156430482|            1979|        2|     article|          first|   NULL|     NULL|                  Insect predators ...|      en|            NULL|           [Biology]|37.894601867199185|    Robert J. Barney|    Robert|        J. Barney|
# |W1000099016|A5026226127|       NULL|S4306462995|            1998|        0|book-chapter|          first|   NULL|     NULL|                  Methodological un...|      en|            NULL|        [Psychology]|               0.0|Marjorie Keniston...|  Marjorie|Keniston McIntosh|
# |W1000061251|A5029093911|       NULL|S4210169064|            2012|        0|     article|          first|   NULL|     NULL|                  THE NEW STATUS QU...|      de|            NULL|[Economics, Philo...|               0.0|María Esther Aret...|     María|Esther Aretxabala|
# |W1000015796|A5032245741|       NULL|S4306543241|            2012|        0|     article|          first|   NULL|     NULL|                  Sino-U.S. Film Ag...|      en|            NULL|[Art, Materials s...|               0.0|           Hong Wang|      Hong|             Wang|
# |W1000025177|A5032287056|       NULL|S4306546324|            2001|        0|     article|          first|   NULL|     NULL|            政府上网：发展、功能及挑战|   zh-cn|            NULL|  [Computer science]|               0.0|              徐华礼|    徐华礼|                 |
# |W1000168890|A5034009108|       NULL|S4306549941|            2012|        0|     article|          first|   NULL|     NULL|再谈《古今乐纂》“汉乐坐部”史料中的问题|   zh-cn|            NULL|  [Computer science]|               0.0|              董晓明|    董晓明|                 |
# |W1000001167|A5035465700|       NULL|S4306559942|            2000|        0|     article|           last|   NULL|     NULL|             复合固体酸TiO2—SnO2—Al...|   zh-cn|            NULL|  [Computer science]|               0.0|                金辉|      金辉|                 |
# |W1000072191|A5039759752|       NULL|S4306557984|            2011|        0|     article|         middle|   NULL|     NULL|           白血病相关抗原MLAA-34 HL...|   zh-cn|            NULL|          [Medicine]|               0.0|              古流芳|    古流芳|                 |
# |W1000076858|A5043361003|       NULL|S4306543357|            2010|        0|     article|          first|   NULL|     NULL|       “丹江记忆”与“博格达情结”——论...|   zh-cn|            NULL|  [Computer science]|               0.0|              郑丽娜|    郑丽娜|                 |
# |W1000028275|A5049779829|       NULL|S4306542153|            2012|        0|     article|           last|   NULL|     NULL| 微量元素铁、锰、铜对水稻生长的影响...|   zh-cn|            NULL|  [Computer science]|               0.0|              曾大力|    曾大力|                 |
# | W100002993|A5054587316|       NULL|       NULL|            1987|        2|book-chapter|          first|   NULL|     NULL|                  Theoretical and E...|      en|            NULL|[Computer science...|62.836702098043695|Elzbieta A. Marsz...|  Elzbieta|     A. Marszalec|
# +-----------+-----------+-----------+-----------+----------------+---------+------------+---------------+-------+---------+--------------------------------------+--------+----------------+--------------------+------------------+--------------------+----------+-----------------+
# only showing top 20 rows

# %%
unmatched_pubs_scanR.show()
# Out:
# +--------------------+--------------------+--------------------+------------+--------------------+--------------------+----------------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------+--------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------+-----------+----+--------+--------------------+------------+-------------------+--------------------+-------+
# |                  id|        affiliations|             authors|authorsCount|       autocompleted|autocompletedJournal|autocompletedPublisher|bso_local_affiliations|          co_authors|          co_domains|     co_institutions|         co_software|       co_structures|              doiUrl|             domains|         externalIds| isOa|            keywords|         landingPage|          oaEvidence|              pdfUrl|productionType|projects|    publicationDate|           softwares|              source|             summary|               title|           type|vector_text|year|language|               idref|   firstName|           lastName|            fullName|initial|
# +--------------------+--------------------+--------------------+------
http://doi.org/10...|                NULL|                NULL|   publication|    NULL|2015-03-17T00:00:00|[{[All analyses w...|{false, false, [0...|{Background: Acut...|Renal haemodynami...|journal-article|       NULL|2015|      en|086036904###b. al...|           B|       ALLAOUCHICHE|      B ALLAOUCHICHE|      B|
# |doi10.23736/s0375...|[{{INSERM, INSERM...|{[{NULL, NULL, NU...|           7|[doi10.23736/s037...|[Minerva Anestesi...|  [Edizioni Minerva...|  [130008584, 19691...|[idref111387337##...|                NULL|[266900273###FR_H...|                NULL|[201320572J###FR_...|http://doi.org/10...|[{Q186290, 1, Q18...|[{10.23736/s0375-...|false|                NULL|http://doi.org/10...|                NULL|                NULL|   publication|    NULL|2021-11-01T00:00:00|                NULL|{false, false, [0...|                NULL|Correlation betwe...|journal-article|       NULL|2021|      en|086036904###berna...|     Bernard|       ALLAOUCHICHE|Bernard ALLAOUCHICHE|      B|
# |doi10.3390/mol2ne...|[{{ENS Rennes, NU...|{NULL, {idref2452...|           5|[doi10.3390/mol2n...|[Proceedings of M...|                [MDPI]|                  NULL|[idref245218580##...|                NULL|[199406075###FR_E...|                NULL|                NULL|http://doi.org/10...|[{Q3273039, 1, Q3...|[{10.3390/mol2net...| true|{[Iron molydates,...|http://doi.org/10...|{publisher, https...|https://sciforum....|   publication|    NULL|2018-11-13T00:00:00|                NULL|{false, false, NU...|{In this paper, F...|&lt;strong&gt;Pol...|    proceedings|       NULL|2018|      en|245218580###thame...|      Thamer|              ALOUI|        Thamer ALOUI|      T|
# +--------------------+--------------------+--------------------+------------+--------------------+--------------------+----------------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------+--------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------+-----------+----+--------+--------------------+------------+-------------------+--------------------+-------+
# only showing top 20 rows

# %%
unmatched_au_oa.show()
# Out:
# +-----------+-----------+-----------+-----------+----------------+---------+------------+---------------+-------+---------+--------------------------------------+--------+----------------+--------------------+------------------+--------------------+----------+-----------------+
# |  author_id|    work_id|    inst_id|  source_id|publication_year|citations|        type|author_position|country|inst_type|                                 title|language|         version|              fields|     rank_by_field|        display_name|first_name|        last_name|
# +-----------+-----------+-----------+-----------+----------------+---------+------------+---------------+-------+---------+--------------------------------------+--------+----------------+--------------------+------------------+--------------------+----------+-----------------+
# |A5005748252|W1000086972|       NULL|       NULL|            2001|        0|     article|          first|   NULL|     NULL|                  PELICAN - Pricing...|      en|            NULL|[Biology, Busines...|               0.0|   Charles Oppenheim|   Charles|        Oppenheim|
# |A5007324954|W1000006948|       NULL|S4306552639|            1994|        0|     article|           last|   NULL|     NULL|        采伐调查设计(作业)成本速算初探|   zh-cn|            NULL|  [Computer science]|               0.0|              魏彦彬|    魏彦彬|                 |
# |A5011035542| W100000914|       NULL|S4210194219|            1973|        0|     article|          first|   NULL|     NULL|                  Geology and miner...|      en|publishedVersion|           [Geology]|               0.0|           R.B. Hall|      R.B.|             Hall|
# |A5012306549|W1000062617|       NULL|S4210182227|            2005|        0|     article|          first|   NULL|     NULL|                  Liberale Demokrat...|      de|            NULL|[Philosophy, Poli...|               0.0|       Richard Saage|   Richard|            Saage|
# |A5015056658| W100007976|       NULL|S4306537626|            2014|        0|     article|           last|   NULL|     NULL|                  المشكلات التي توا...|      ar|            NULL|  [Computer science]|               0.0|       وبشار عينبوسي|     وبشار|          عينبوسي|
# |A5015778850| W100012731|       NULL|S4306526548|            2000|        0|     article|           last|   NULL|     NULL|                  Effects of water ...|      en|            NULL|[Biology, Environ...|               0.0|   J. Silveira Filho|        J.|   Silveira Filho|
# |A5017183161|W1000132866|       NULL|S4306554696|            2001|        0|     article|           last|   NULL|     NULL|  抓农业生态环境建设 走质量效益农业...|   zh-cn|            NULL|  [Computer science]|               0.0|              董玉芹|    董玉芹|                 |
# |A5017812851|W1000054759|I4210098952|  S76304953|            2010|        1|     article|           last|     US|  company|                  The ArgusTM II Re...|      en|            NULL|[Computer science...|50.485857146070195|      R.J. Greenberg|      R.J.|        Greenberg|
# |A5018492358|W1000046334|       NULL|S4306544079|            2014|        0|     article|         middle|   NULL|     NULL|  猪皮下和内脏脂肪组织中G蛋白偶联受...|   zh-cn|            NULL|           [Biology]|               0.0|              王红梅|    王红梅|                 |
# |A5022417632| W100002715|       NULL|S2764680408|            2003|       59|book-chapter|          first|   NULL|     NULL|                  Root Exudates: an...|      en|            NULL|        [Philosophy]|  94.4001485453826|   Inderjit Inderjit|  Inderjit|                 |
# |A5023100723|W1000049952|       NULL| S156430482|            1979|        2|     article|          first|   NULL|     NULL|                  Insect predators ...|      en|            NULL|           [Biology]|37.894601867199185|    Robert J. Barney|    Robert|        J. Barney|
# |A5026226127|W1000099016|       NULL|S4306462995|            1998|        0|book-chapter|          first|   NULL|     NULL|                  Methodological un...|      en|            NULL|        [Psychology]|               0.0|Marjorie Keniston...|  Marjorie|Keniston McIntosh|
# |A5029093911|W1000061251|       NULL|S4210169064|            2012|        0|     article|          first|   NULL|     NULL|                  THE NEW STATUS QU...|      de|            NULL|[Economics, Philo...|               0.0|María Esther Aret...|     María|Esther Aretxabala|
# |A5032287056|W1000025177|       NULL|S4306546324|            2001|        0|     article|          first|   NULL|     NULL|            政府上网：发展、功能及挑战|   zh-cn|            NULL|  [Computer science]|               0.0|              徐华礼|    徐华礼|                 |
# |A5034009108|W1000168890|       NULL|S4306549941|            2012|        0|     article|          first|   NULL|     NULL|再谈《古今乐纂》“汉乐坐部”史料中的问题|   zh-cn|            NULL|  [Computer science]|               0.0|              董晓明|    董晓明|                 |
# |A5035465700|W1000001167|       NULL|S4306559942|            2000|        0|     article|           last|   NULL|     NULL|             复合固体酸TiO2—SnO2—Al...|   zh-cn|            NULL|  [Computer science]|               0.0|                金辉|      金辉|                 |
# |A5039759752|W1000072191|       NULL|S4306557984|            2011|        0|     article|         middle|   NULL|     NULL|           白血病相关抗原MLAA-34 HL...|   zh-cn|            NULL|          [Medicine]|               0.0|              古流芳|    古流芳|                 |
# |A5043361003|W1000076858|       NULL|S4306543357|            2010|        0|     article|          first|   NULL|     NULL|       “丹江记忆”与“博格达情结”——论...|   zh-cn|            NULL|  [Computer science]|               0.0|              郑丽娜|    郑丽娜|                 |
# |A5049779829|W1000028275|       NULL|S4306542153|            2012|        0|     article|           last|   NULL|     NULL| 微量元素铁、锰、铜对水稻生长的影响...|   zh-cn|            NULL|  [Computer science]|               0.0|              曾大力|    曾大力|                 |
# |A5054587316| W100002993|       NULL|       NULL|            1987|        2|book-chapter|          first|   NULL|     NULL|                  Theoretical and E...|      en|            NULL|[Computer science...|62.836702098043695|Elzbieta A. Marsz...|  Elzbieta|     A. Marszalec|
# +-----------+-----------+-----------+-----------+----------------+---------+------------+---------------+-------+---------+--------------------------------------+--------+----------------+--------------------+------------------+--------------------+----------+-----------------+
# only showing top 20 rows

# %%
unmatched_au_scanR.show()
# Out:
# +--------------------+--------------------+--------------------+------------+--------------------+--------------------+----------------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------+--------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------+-----------+----+--------+------------+-------------------+--------------------+-------+
# |               idref|        affiliations|             authors|authorsCount|       autocompleted|autocompletedJournal|autocompletedPublisher|bso_local_affiliations|          co_authors|          co_domains|     co_institutions|         co_software|       co_structures|              doiUrl|             domains|         externalIds|                  id| isOa|            keywords|         landingPage|          oaEvidence|              pdfUrl|productionType|projects|    publicationDate|           softwares|              source|             summary|               title|           type|vector_text|year|language|   firstName|           lastName|            fullName|initial|
# +--------------------+--------------------+--------------------+------------+--------------------+--------------------+----------------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------+--------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------+-----------+----+--------+------------+-------------------+--------------------+-------+
# |Jonathan A Christ...|                NULL|{NULL, NULL, Jona...|           9|[doi10.1175/jcli-...|[Journal of Clima...|  [American Meteoro...|                  NULL|                NULL|                NULL|                NULL|                NULL|                NULL|http://doi.org/10...|[{Q1337681, 1, Q1...|[{10.1175/jcli-d-...|doi10.1175/jcli-d...| true|                NULL|http://doi.org/10...|{publisher, https...|https://journals....|   publication|    NULL|2023-02-01T00:00:00|                NULL|{false, false, [0...|                NULL|Anchoring Intrase...|journal-article|       NULL|2023|      en|    Jonathan|   A Christophersen|Jonathan A Christ...|      J|
# | Raymond A Ezejiofor|[{NULL, shs, NULL...|{[{NULL, NULL, NU...|           3|[halhalshs-013597...|                NULL|  [International Ac...|  [465167, shs, ao-...|                NULL|[Q2663158###FOREN...|                NULL|                NULL|                NULL|                NULL|[{Q2663158, 2, Q2...|[{halshs-01359758...|  halhalshs-01359758| true|{[Forensic accoun...|https://hal.scien...|{repository, NULL...|https://shs.hal.s...|   publication|    NULL|2016-09-03T00:00:00|                NULL|{false, false, NU...|{This study deter...|IMPACT OF FORENSI...|journal-article|       NULL|2016|      en|     Raymond|        A Ezejiofor| Raymond A Ezejiofor|      R|
# |   A K Rakhmetullina|                NULL|{NULL, NULL, NULL...|           5|[doi10.32014/2019...|[SERIES OF BIOLOG...|  [National Academy...|                  NULL|                NULL|                NULL|                NULL|                NULL|                NULL|http://doi.org/10...|[{Q1115133, 1, Q1...|[{10.32014/2019.2...|doi10.32014/2019....| true|                NULL|http://doi.org/10...|{publisher, https...|https://doi.org/1...|   publication|    NULL|2019-10-15T00:00:00|                NULL|{false, true, [22...|                NULL|RICE miRNAs ARE P...|journal-article|       NULL|2019|      en|        NULL|  A K Rakhmetullina|   A K Rakhmetullina|   NULL|
# |     Hatem A Rashwan|[{{Toulouse INP, ...|{[{NULL, NULL, NU...|           4|[doi10.1016/j.pat...|[Pattern Recognit...|            [Elsevier]|  [193113818, 19951...|                NULL|                NULL|[grid.417764.7###...|                NULL|                NULL|http://doi.org/10...|[{Q128581, 2, Q12...|[{10.1016/j.patre...|doi10.1016/j.patr...|false|{[Breast cancer, ...|http://doi.org/10...|                NULL|                NULL|   publication|    NULL|