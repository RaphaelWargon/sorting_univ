# %%
import os
base_path = os.path.dirname(os.path.abspath(""))
base_path = base_path + "/headers/"
print(base_path)
header_path = base_path + 'header_data_treatment.ipynb'
app_name = 'merge_universities'
# %run -i $header_path
# Out:
# C:\Users\raphael.wargon\Documents\GitHub\sorting_univ\script/headers/
# merge_universities
# initalizing spark nlp session w gpu

# %% [markdown]
# # Loading data

# %%
inst =  spark.read.parquet('file:\\' + save_path + 'intermediary\\inst_fr.parquet')

# %%
budget =  spark.read.json('file:\\' + scanR_path + '\\fr-esr-operateurs-indicateurs-financiers.json')

# %%
budget.printSchema()
# Out:
# root
#  |-- academie: string (nullable = true)
#  |-- acquisitions_d_immobilisations: double (nullable = true)
#  |-- anr_hors_investissements_d_avenir: double (nullable = true)
#  |-- anr_investissements_d_avenir: double (nullable = true)
#  |-- autres_ressources_propres: double (nullable = true)
#  |-- autres_subventions: double (nullable = true)
#  |-- besoin_en_fonds_de_roulement: double (nullable = true)
#  |-- caf_acquisitions_d_immobilisations: double (nullable = true)
#  |-- caf_produits_encaissables: double (nullable = true)
#  |-- capacite_d_autofinancement: double (nullable = true)
#  |-- charges_de_fonctionnement_decaissables: double (nullable = true)
#  |-- charges_de_personnel: double (nullable = true)
#  |-- charges_de_personnel_produits_encaissables: double (nullable = true)
#  |-- charges_decaissables_produits_encaissables: double (nullable = true)
#  |-- charges_externes: double (nullable = true)
#  |-- charges_externes_produits_encaissables: double (nullable = true)
#  |-- code_de_l_academie: string (nullable = true)
#  |-- code_de_la_commune: string (nullable = true)
#  |-- code_de_la_region: string (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- contrats_et_prestations_de_recherche_hors_anr: double (nullable = true)
#  |-- droits_d_inscription: double (nullable = true)
#  |-- etablissement: string (nullable = true)
#  |-- etablissement_id_paysage: string (nullable = true)
#  |-- excedent_brut_d_exploitation_ebe: double (nullable = true)
#  |-- exercice: string (nullable = true)
#  |-- fonds_de_roulement_en_jours_de_charges_decaissables: double (nullable = true)
#  |-- fonds_de_roulement_net_global: double (nullable = true)
#  |-- formation_continue_diplomes_propres_et_vae: double (nullable = true)
#  |-- produits_de_fonctionnement_encaissables: double (nullable = true)
#  |-- rce: string (nullable = true)
#  |-- recettes_propres: double (nullable = true)
#  |-- region: string (nullable = true)
#  |-- ressources_propres_encaissables: double (nullable = true)
#  |-- ressources_propres_produits_encaissables: double (nullable = true)
#  |-- resultat_net_comptable: double (nullable = true)
#  |-- resultat_net_comptable_hors_sie: double (nullable = true)
#  |-- solde_budgetaire: double (nullable = true)
#  |-- source: string (nullable = true)
#  |-- subventions_de_la_region: double (nullable = true)
#  |-- subventions_union_europeenne: double (nullable = true)
#  |-- taux_de_remuneration_des_permanents: double (nullable = true)
#  |-- taxe_d_apprentissage: double (nullable = true)
#  |-- tresorerie: double (nullable = true)
#  |-- tresorerie_en_jours_de_charges_decaissables: double (nullable = true)
#  |-- uai_identifiant: string (nullable = true)
#  |-- vague: string (nullable = true)
#  |-- valorisation: double (nullable = true)

# %%
budget.select('etablissement','etablissement_id_paysage').distinct().count()
# Out:
# 201

# %% [markdown]
# # Normalisation functions for the match

# %%
from nltk.corpus import stopwords
print(stopwords.fileids())
stopwords_dict = {}
for language in stopwords.fileids():
    stopwords_dict[language.capitalize()] = stopwords.words(language)
    
def rm_stopwords(x,y):
    try:
        list_x = x.split(' ')
        list_y = y
        return(' '.join([word for word in list_x if word not in list_y]))
    except:
        return(x)
udf_rm_stopwords = func.udf(rm_stopwords)
# Out:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']

# %%
stopwords_dict['French'] = stopwords_dict['French'] + ['l']

# %%
from nltk.stem.snowball import FrenchStemmer
from nltk.stem import PorterStemmer

# %%
def stemmer(x,y):
    try:
        if y == 'fr' or y == 'French' or y == 'Français':
            output = ' '.join([FrenchStemmer().stem(word) for word in x.split(' ')])
            return(output)
        else:
            output = ' '.join([PorterStemmer().stem(word) for word in x.split(' ')])
            return(output)
    except:
        return(x)
udf_stemmer = func.udf(stemmer)

# %%
import unidecode
def unidecode_debug(x):
    try:
        return unidecode.unidecode(x) if x is not None else None
       
    except:
        return(x)

udf_unidecode = func.udf(unidecode_debug, StringType())

# %% [markdown]
# # Merge
#
# In this part, we use observation-level characteristics to merge institutions between the two databases.
# In each step :
# * we match by the characteristics related to the step
# * we remove duplicates in this characteristic.
#
# We perform this merge on  full name of the institution, acronym of the institution.

# %% [markdown]
# ## Merge by name
#
# In this part, we need to exclude some matches manually.

# %%
inst.show()
# Out:
# +-----------+--------------------+----------+-----------+--------------------+--------------------+--------------------+--------------------+-------+--------------------+----+--------------------+-------------------+-------------------+---------+---------+---------------+-----------+--------------+
# |    inst_id|                name|      type|       city|        homepage_url|         topic_share|          main_topic|              parent|uni_pub|           parent_id|cnrs|                idex|total_idex_dotation|            type_fr|  secteur|acces_rce|date_first_idex|fusion_date|merged_inst_id|
# +-----------+--------------------+----------+-----------+--------------------+--------------------+--------------------+--------------------+-------+--------------------+----+--------------------+-------------------+-------------------+---------+---------+---------------+-----------+--------------+
# | I193033237|Institut Superieu...| education|   Toulouse|https://www.isae-...|[{Engineering, 0....|         Engineering|[{I193033237, Ins...|      0|        [I193033237]|   0|[idex_annulee_tou...|           56353926|Grand établissement|   public|        0|           2013|       NULL|          NULL|
# |I4210085936|   LABCATAL (France)|   company|  Montrouge|http://www.labcat...|[{Medicine, 1.827...|            Medicine|[{I4210085936, LA...|      0|       [I4210085936]|   0|                NULL|               NULL|              Firme|    privé|        0|           NULL|       NULL|          NULL|
# |I4210090216|Laboratoire de la...|  facility|    St-Malo|http://www.labora...|[{Medicine, 2.086...|            Medicine|[{I4210090216, La...|      0|       [I4210090216]|   0|                NULL|               NULL|          undefined|undefined|        0|           NULL|       NULL|          NULL|
# |I4210096859|Centre Nouvelle A...|  facility|   Bordeaux|https://www.inrae...|[{Computer Scienc...|            Medicine|[{I4210088668, In...|      0|       [I4210088668]|   0|         [isite_e2s]|           29122038|          undefined|   public|        0|           2017|       NULL|          NULL|
# |I4210101037|Laboratoire de Ph...|  facility|    Dunkirk|https://lpca.univ...|[{Chemistry, 0.00...|           Chemistry|[{I2802487185, Un...|      1|[I2802487185, I42...|   1|                NULL|               NULL|         Université|   public|     2010|           NULL|       NULL|          NULL|
# |I4210106601|Virtual Open Syst...|   company|   Grenoble|http://www.virtua...|[{Computer Scienc...|    Computer Science|[{I4210106601, Vi...|      0|       [I4210106601]|   0|                NULL|               NULL|              Firme|    privé|        0|           NULL|       NULL|          NULL|
# |I4210111182|Impeto Medical (F...|   company|      Paris|https://www.impet...|[{Medicine, 1.792...|            Medicine|[{I4210111182, Im...|      0|       [I4210111182]|   0|                NULL|               NULL|              Firme|    privé|        0|           NULL|       NULL|          NULL|
# |I4210131541|ACIES Consulting ...|     other|       Lyon|http://www.acies-...|[{Agricultural an...|Agricultural and ...|[{I4210131541, AC...|      0|       [I4210131541]|   0|                NULL|               NULL|          undefined|undefined|        0|           NULL|       NULL|          NULL|
# |I4210134453|     Fondation ARCAD| nonprofit|      Paris|https://www.fonda...|[{Medicine, 3.013...|            Medicine|[{I4210134453, Fo...|      0|       [I4210134453]|   0|                NULL|               NULL|          undefined|    privé|        0|           NULL|       NULL|          NULL|
# |I4210134684|Ferring Pharmaceu...|   company|   Gentilly|https://www.ferri...|[{Medicine, 4.985...|            Medicine|[{I22138158, Ferr...|      0|         [I22138158]|   0|                NULL|               NULL|              Firme|    privé|        0|           NULL|       NULL|          NULL|
# |I4210141217|            Vizion’R|     other|      Paris|http://vizionr.fr...|[{Medicine, 1.579...|            Medicine|[{I4210141217, Vi...|      0|       [I4210141217]|   0|                NULL|               NULL|          undefined|undefined|        0|           NULL|       NULL|          NULL|
# |I4210141565|Institut de Chimi...|  facility|    Orléans|http://www.icoa.f...|[{Chemistry, 0.01...|           Chemistry|[{I12449238, Univ...|      1|[I12449238, I1294...|   1|                NULL|               NULL|         Université|   public|     2011|           NULL|       NULL|          NULL|
# |I4210152014|Hôpital Georges-C...|healthcare| Champcueil|http://chu-mondor...|[{Medicine, 0.003...|            Medicine|[{I4210130325, Hô...|      0|       [I4210130325]|   0|                NULL|               NULL|          undefined|   public|        0|           NULL|       NULL|          NULL|
# |I4387153895|Maison des Scienc...|  facility|Saint-Denis|http://www.mshpar...|[{Social Sciences...|     Social Sciences|[{I1294671590, Ce...|      1|[I1294671590, I42...|   1|                NULL|               NULL|         Université|   public|     2010|           2012|       NULL|          NULL|
# |I2801819261|Association Futur...| nonprofit|      Paris|https://www.futur...|[{Social Sciences...|     Social Sciences|[{I2801819261, As...|      0|       [I2801819261]|   0|                NULL|               NULL|          undefined|    privé|        0|           NULL|       NULL|          NULL|
# |I4210091226|École Supérieure ...| education|       Caen|http://www.esam-c...|[{Agricultural an...|Agricultural and ...|[{I4210091226, Éc...|      0|       [I4210091226]|   0|                NULL|               NULL|              École|   public|        0|           NULL|       NULL|          NULL|
# |I4210091847|  Cermavein (France)|   company|   Archamps|http://cermavein....|[{Medicine, 4.030...|         Engineering|[{I4210091847, Ce...|      0|       [I4210091847]|   0|                NULL|               NULL|              Firme|    privé|        0|           NULL|       NULL|          NULL|
# |I4210092913|Tethys Instrument...|   company|     Meylan|http://www.tethys...|[{Health Professi...|  Health Professions|[{I4210092913, Te...|      0|       [I4210092913]|   0|                NULL|               NULL|              Firme|    privé|        0|           NULL|       NULL|          NULL|
# |I4210103254|Centre de Microbi...|  facility|      Dijon|http://www7.inra....|[{Agricultural an...|Agricultural and ...|[{I4210088041, Ce...|      1|[I4210088041, I42...|   1|                NULL|               NULL|         Université|   public|        0|           NULL|       NULL|          NULL|
# |I4210109693|Association pour ...|     other|    Bobigny|http://www.arpeal...|[{Biochemistry, G...|Biochemistry, Gen...|[{I4210109693, As...|      0|       [I4210109693]|   0|                NULL|               NULL|          undefined|    privé|        0|           NULL|       NULL|          NULL|
# +-----------+--------------------+----------+-----------+--------------------+--------------------+--------------------+--------------------+-------+--------------------+----+--------------------+-------------------+-------------------+---------+---------+---------------+-----------+--------------+
# only showing top 20 rows

# %%
fr_oa_normalized_names = (inst.withColumn('is_oa', func.lit(1))
                           #.filter(~func.col('inst_id').isin(all_matched_inst_oa))
                              .withColumn('stopwords_fr',func.array([func.lit(x) for x in stopwords_dict['French']]))
                              .withColumn('stopwords_en',func.array([func.lit(x) for x in stopwords_dict['English']]))

                    .filter(func.col('name').isNotNull())
                   .withColumn('name', func.regexp_replace(func.col('name'), r"\([A-z\s]*\)", ''))
                  .withColumn('name', func.regexp_replace(func.col('name'),  r"""[!\"#$%&'()*+,\-.\/:;<=>?@\[\\\]^_`{|}~]""", ' '))
                   .withColumn('name', func.regexp_replace(func.col('name'),  r"\s{2,}", ' ')) 
                  .withColumn('name', func.regexp_replace(func.col('name'), r"\s$", ''))
                        
                              .withColumn('name', udf_rm_stopwords(func.lower(func.col('name')),func.col('stopwords_fr')))
                              .withColumn('name', udf_rm_stopwords(func.lower(func.col('name')), func.col('stopwords_en')))
                   .filter(func.col('name').isNotNull())
                   .filter(func.col('name') != "")
                   .withColumn('name', udf_unidecode(func.col('name')))
                    .withColumn('name', func.lower(func.col('name')))
                 # .na.drop(subset = 'name')

                         .select('inst_id','name')

                         )
fr_oa_normalized_names.cache()
fr_oa_normalized_names.show()
# Out:
# +-----------+--------------------+
# |    inst_id|                name|
# +-----------+--------------------+
# | I193033237|institut superieu...|
# |I4210085936|            labcatal|
# |I4210090216|     laboratoire mer|
# |I4210096859|centre nouvelle a...|
# |I4210101037|laboratoire physi...|
# |I4210106601|virtual open systems|
# |I4210111182|      impeto medical|
# |I4210131541|acies consulting ...|
# |I4210134453|     fondation arcad|
# |I4210134684|ferring pharmaceu...|
# |I4210141217|            vizion'r|
# |I4210141565|institut chimie o...|
# |I4210152014|hopital georges c...|
# |I4387153895|maison sciences h...|
# |I2801819261|association futur...|
# |I4210091226|ecole superieure ...|
# |I4210091847|           cermavein|
# |I4210092913|  tethys instruments|
# |I4210103254|centre microbiolo...|
# |I4210109693|association reche...|
# +-----------+--------------------+
# only showing top 20 rows

# %%
fr_oa_normalized_names.filter(func.col('name')=="evosens").show()
# Out:
# +-----------+-------+
# |    inst_id|   name|
# +-----------+-------+
# |I4210147280|evosens|
# +-----------+-------+

# %%
budget_normalized_names = (budget
                           .withColumn('stopwords_fr',func.array([func.lit(x) for x in stopwords_dict['French']]))
                           .withColumn('name', udf_rm_stopwords(func.lower(func.col('etablissement')), func.col('stopwords_fr')))

                           .withColumn('name', func.regexp_replace(func.col('name'),   r"""[!\"#$%&'()*+,\-.\/:;<=>?@\[\\\]^_`{|}~]""", ' '))
                           .withColumn('name', udf_rm_stopwords(func.lower(func.col('name')), func.col('stopwords_fr')))
                           .withColumn('name', udf_unidecode(func.col('name')))
                           .withColumn('name', func.regexp_replace(func.col('name'),  r"\s{2,}", ' '))
                           .withColumn('name', func.regexp_replace(func.col('name'), r"\([A-z\s]*\)", ''))
                           .withColumn('name', func.regexp_replace(func.col('name'), r"\s$", ''))
                           .filter(func.col('name').isNotNull())
                           .filter(func.col('name') != "")

                           .select('etablissement','etablissement_id_paysage','name')
                         )
budget_normalized_names.cache()
budget_normalized_names.show()
# Out:
# +--------------------+------------------------+--------------------+
# |       etablissement|etablissement_id_paysage|                name|
# +--------------------+------------------------+--------------------+
# |Observatoire de l...|                   8JlNN|observatoire cote...|
# |Observatoire de l...|                   8JlNN|observatoire cote...|
# |Observatoire de l...|                   8JlNN|observatoire cote...|
# |Université NICE -...|                   7CYWd|universite nice s...|
# |COMUE université ...|                   RDy6Q|comue universite ...|
# |COMUE université ...|                   RDy6Q|comue universite ...|
# |EPE université Cô...|                   s3t8T|epe universite co...|
# |EPE université Cô...|                   s3t8T|epe universite co...|
# |Université de tec...|                   8tVLr|universite techno...|
# |Université de tec...|                   8tVLr|universite techno...|
# |Institut d'études...|                   G8QBG|institut etudes p...|
# |Institut d'études...|                   G8QBG|institut etudes p...|
# |Ecole centrale de...|                   1tI7C|ecole centrale ma...|
# |Ecole centrale de...|                   1tI7C|ecole centrale ma...|
# |Université AIX MA...|                   xJdyB|universite aix ma...|
# |Université AIX MA...|                   xJdyB|universite aix ma...|
# |Université AIX MA...|                   xJdyB|universite aix ma...|
# |Université CAEN -...|                   p25Q3|universite caen b...|
# |Université CAEN -...|                   p25Q3|universite caen b...|
# |Université CAEN -...|                   p25Q3|universite caen b...|
# +--------------------+------------------------+--------------------+
# only showing top 20 rows

# %%
merge_inst_by_names = (fr_oa_normalized_names
                       .filter(func.col('name')!='')

                       .join(budget_normalized_names.filter(func.col('name')!='')
                             ,on = ['name'], how = 'inner')
                        .distinct()
                        .withColumn('several_id', 
                         ((func.size(func.collect_set('inst_id').over(Window.partitionBy('name')))>1) |
                         (func.size(func.collect_set('etablissement_id_paysage').over(Window.partitionBy('name')))>1)).cast('int'))

                  )

# %%
merge_inst_by_names.persist()
merge_inst_by_names.select('etablissement_id_paysage','inst_id').distinct().count()
# Out:
# 63

# %%
merge_inst_by_names.filter(func.col('name').contains('bordeaux')).show(truncate = False)
# Out:
# +-------------------------------+-----------+----------------------------------+------------------------+----------+
# |name                           |inst_id    |etablissement                     |etablissement_id_paysage|several_id|
# +-------------------------------+-----------+----------------------------------+------------------------+----------+
# |universite bordeaux            |I15057530  |Université BORDEAUX               |90I54                   |0         |
# |institut polytechnique bordeaux|I4210160189|Institut polytechnique de Bordeaux|S88MV                   |0         |
# +-------------------------------+-----------+----------------------------------+------------------------+----------+

# %%
unmatched = (budget_normalized_names
             .join(merge_inst_by_names.select('etablissement_id_paysage'), on = 'etablissement_id_paysage', how = 'leftanti')
            )
unmatched.show(truncate = False)
# Out:
# +------------------------+--------------------------------------------+---------------------------------------+
# |etablissement_id_paysage|etablissement                               |name                                   |
# +------------------------+--------------------------------------------+---------------------------------------+
# |8JlNN                   |Observatoire de la Côte d'Azur              |observatoire cote azur                 |
# |8JlNN                   |Observatoire de la Côte d'Azur              |observatoire cote azur                 |
# |8JlNN                   |Observatoire de la Côte d'Azur              |observatoire cote azur                 |
# |7CYWd                   |Université NICE - SOPHIA-ANTIPOLIS          |universite nice sophia antipolis       |
# |RDy6Q                   |COMUE université Côte d’Azur                |comue universite cote d'azur           |
# |RDy6Q                   |COMUE université Côte d’Azur                |comue universite cote d'azur           |
# |s3t8T                   |EPE université Côte d’Azur                  |epe universite cote d'azur             |
# |s3t8T                   |EPE université Côte d’Azur                  |epe universite cote d'azur             |
# |G8QBG                   |Institut d'études politiques AIX-EN-PROVENCE|institut etudes politiques aix provence|
# |G8QBG                   |Institut d'études politiques AIX-EN-PROVENCE|institut etudes politiques aix provence|
# |1tI7C                   |Ecole centrale de Marseille                 |ecole centrale marseille               |
# |1tI7C                   |Ecole centrale de Marseille                 |ecole centrale marseille               |
# |xJdyB                   |Université AIX MARSEILLE                    |universite aix marseille               |
# |xJdyB                   |Université AIX MARSEILLE                    |universite aix marseille               |
# |xJdyB                   |Université AIX MARSEILLE                    |universite aix marseille               |
# |p25Q3                   |Université CAEN - BASSE-NORMANDIE           |universite caen basse normandie        |
# |p25Q3                   |Université CAEN - BASSE-NORMANDIE           |universite caen basse normandie        |
# |p25Q3                   |Université CAEN - BASSE-NORMANDIE           |universite caen basse normandie        |
# |p25Q3                   |Université CAEN - BASSE-NORMANDIE           |universite caen basse normandie        |
# |p25Q3                   |Université CAEN - BASSE-NORMANDIE           |universite caen basse normandie        |
# +------------------------+--------------------------------------------+---------------------------------------+
# only showing top 20 rows

# %%
unmatched.distinct().toPandas().to_csv( scanR_path + '\\budget_inst_to_match.csv')

# %%
handmatched = spark.read.csv('file:///' + scanR_path + '\\budget_inst_handmatched.csv', header = True)

# %%
all_matches = (merge_inst_by_names
               .select('etablissement_id_paysage', 'inst_id').distinct()
               .unionAll(handmatched
               .select('etablissement_id_paysage', 'inst_id').distinct()
                        )
              )

# %%
all_matches.count()
# Out:
# 198

# %%
all_matches.filter(func.col('inst_id')=="I4210137101").show()
# Out:
# +------------------------+-------+
# |etablissement_id_paysage|inst_id|
# +------------------------+-------+
# +------------------------+-------+

# %%
budget.select('exercice').distinct().collect()
# Out:
# [Row(exercice='2016'),
#  Row(exercice='2012'),
#  Row(exercice='2020'),
#  Row(exercice='2019'),
#  Row(exercice='2017'),
#  Row(exercice='2014'),
#  Row(exercice='2013'),
#  Row(exercice='2018'),
#  Row(exercice='2011'),
#  Row(exercice='2022'),
#  Row(exercice='2023'),
#  Row(exercice='2021'),
#  Row(exercice='2024'),
#  Row(exercice='2015'),
#  Row(exercice='2010')]

# %%
inst_budget = (inst
               .withColumn('parent_id', func.explode_outer(func.col('parent.parent_id')))
               .join(all_matches.withColumnRenamed('inst_id','parent_id'), on = 'parent_id', how = 'left')
               .join(budget.withColumnRenamed('exercice', 'year'), on = 'etablissement_id_paysage', how = 'left')
               .groupBy('inst_id','year')
               .agg(*[func.sum(func.col(col)).alias(col) for col in budget.columns
                      if col not in ['etablissement','etablissement_id_paysage','exercice','academie','code_de_l_academie','code_de_la_commune','code_de_la_region',
                                     'region','source','commune','uai_identifiant','vague']
                     ]
                   )
              )

# %%
inst_budget.show()
# Out:
# +-----------+----+------------------------------+---------------------------------+----------------------------+-------------------------+------------------+----------------------------+----------------------------------+-------------------------+--------------------------+--------------------------------------+--------------------+------------------------------------------+------------------------------------------+----------------+--------------------------------------+---------------------------------------------+--------------------+--------------------------------+---------------------------------------------------+-----------------------------+------------------------------------------+---------------------------------------+------+------------------+-------------------------------+----------------------------------------+----------------------+-------------------------------+----------------+------------------------+----------------------------+-----------------------------------+--------------------+-------------------+-------------------------------------------+------------------+
# |    inst_id|year|acquisitions_d_immobilisations|anr_hors_investissements_d_avenir|anr_investissements_d_avenir|autres_ressources_propres|autres_subventions|besoin_en_fonds_de_roulement|caf_acquisitions_d_immobilisations|caf_produits_encaissables|capacite_d_autofinancement|charges_de_fonctionnement_decaissables|charges_de_personnel|charges_de_personnel_produits_encaissables|charges_decaissables_produits_encaissables|charges_externes|charges_externes_produits_encaissables|contrats_et_prestations_de_recherche_hors_anr|droits_d_inscription|excedent_brut_d_exploitation_ebe|fonds_de_roulement_en_jours_de_charges_decaissables|fonds_de_roulement_net_global|formation_continue_diplomes_propres_et_vae|produits_de_fonctionnement_encaissables|   rce|  recettes_propres|ressources_propres_encaissables|ressources_propres_produits_encaissables|resultat_net_comptable|resultat_net_comptable_hors_sie|solde_budgetaire|subventions_de_la_region|subventions_union_europeenne|taux_de_remuneration_des_permanents|taxe_d_apprentissage|         tresorerie|tresorerie_en_jours_de_charges_decaissables|      valorisation|
# +-----------+----+------------------------------+---------------------------------+----------------------------+-------------------------+------------------+----------------------------+----------------------------------+-------------------------+--------------------------+--------------------------------------+--------------------+------------------------------------------+------------------------------------------+----------------+--------------------------------------+---------------------------------------------+--------------------+--------------------------------+---------------------------------------------------+-----------------------------+------------------------------------------+---------------------------------------+------+------------------+-------------------------------+----------------------------------------+----------------------+-------------------------------+----------------+------------------------+----------------------------+-----------------------------------+--------------------+-------------------+-------------------------------------------+------------------+
# |I4210126950|2014|                 3.801811468E7|                        6218391.5|                  6657143.25|            4.045817289E7|     1.133108114E7|              -1.640104089E7|                         144.04092|             15.545479735|             3.260564586E7|                  3.9367853466999996E8|                NULL|                              107.44292452|                              183.30332808|   8.017866383E7|                           65.09575126|                                   6426298.65|          9872136.11|                    3.12970188E7|                                       122.06467123|                5.979442982E7|                             1.612836358E7|                   4.2694827659000003E8|4030.0|    1.2154823047E8|                 1.2154823047E8|                             89.49345346|         1.793297425E7|                           NULL|            NULL|              5485961.83|           5516874.359999999|                   81.9335956097996|           5025400.9|7.619547071000001E7|                               163.17218365|         321459.23|
